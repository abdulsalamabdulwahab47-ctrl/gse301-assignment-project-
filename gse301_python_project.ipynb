# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulsalamabdulwahab47-ctrl/gse301-assignment-project-/blob/main/gse301_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# ============================================
# [span_4](start_span)PART 1: DATA COLLECTION AND STORAGE[span_4](end_span)
# ============================================

# [span_5](start_span)Task 1.2: Fixed department information (Tuple)[span_5](end_span)
DEPT_INFO = ("Computer Science", "Faculty of Technology", 2025)

# [span_6](start_span)Task 1.2: Set for unique courses[span_6](end_span)
unique_courses = {"Python", "Statistics", "Data Science", "Algorithms", "Database Management"}

# [span_7](start_span)Task 1.1 & 1.2: Initial Student Data (List of dictionaries)[span_7](end_span)
students = [
    {
        "name": "Rasheed Fatia",
        "matric": "23/60AC389",
        "age": 21,
        "cgpa": 4.81,
        "is_active": True,
        "courses": ["Python", "Data Science", "Statistics"],
        "grades": {"Python": "A", "Data Science": "A", "Statistics": "A"},
        "outstanding_courses": 0
    },
    {
        "name": "Yusuf Adeoye",
        "matric": "23/70JC093",
        "age": 22,
        "cgpa": 3.45,
        "is_active": True,
        "courses": ["Python", "Algorithms"],
        "grades": {"Python": "B", "Algorithms": "A"},
        "outstanding_courses": 0
    },
    {
        "name": "Moses Oyedele",
        "matric": "22/50EB112",
        "age": 23,
        "cgpa": 2.10,
        "is_active": True,
        "courses": ["Database Management"],
        "grades": {"Database Management": "C"},
        "outstanding_courses": 2
    },
    {
        "name": "Timi Abidoye",
        "matric": "23/40BC001",
        "age": 20,
        "cgpa": 4.20,
        "is_active": True,
        "courses": ["Python", "Statistics"],
        "grades": {"Python": "A", "Statistics": "B"},
        "outstanding_courses": 0
    },
    {
        "name": "Nimah Nina",
        "matric": "23/10AB005",
        "age": 19,
        "cgpa": 3.95,
        "is_active": False,
        "courses": ["Algorithms"],
        "grades": {"Algorithms": "A"},
        "outstanding_courses": 1
    }
]

# ============================================
# [span_8](start_span)PART 2: DATA PROCESSING AND LOGIC[span_8](end_span)
# ============================================

# [span_9](start_span)Task 2.1: Conditional Statements for Grading[span_9](end_span)
def get_grade_feedback(score):
    if score >= 70:
        grade = "A"
    elif score >= 60:
        grade = "B"
    elif score >= 50:
        grade = "C"
    elif score >= 45:
        grade = "D"
    elif score >= 40:
        grade = "E"
    else:
        grade = "F"

    # [span_10](start_span)Task 2.1: MATCH CASE for feedback[span_10](end_span)
    match grade:
        case "A": feedback = "Excellent work!"
        case "B": feedback = "Very good performance."
        case "C": feedback = "Good, but there is room for improvement."
        case "D" | "E": feedback = "You passed, but need to work harder."
        case "F": feedback = "Fail. Please see your academic adviser."
        case _: feedback = "Invalid grade."

    return grade, feedback

# ============================================
# [span_11](start_span)PART 3: ANALYSIS AND REPORTING[span_11](end_span)
# ============================================

# [span_12](start_span)Task 3.1: List Operations and Slicing[span_12](end_span)
def show_analysis():
    assignment_scores = [85, 92, 78, 65, 88, 72, 95, 60, 81, 74]
    print(f"Top 3 scores (Slicing): {sorted(assignment_scores, reverse=True)[:3]}")
    print(f"Last 5 scores (Negative Indexing): {assignment_scores[-5:]}")
    print(f"Every other score (Step Slicing): {assignment_scores[::2]}")

# [span_13](start_span)Task 3.2: Set Operations[span_13](end_span)
def show_set_ops():
    set_pass = {"Rasheed Fatia", "Yusuf Adeoye", "Timi Abidoye", "Nimah Nina"}
    set_merit = {"Rasheed Fatia", "Timi Abidoye"}

    print(f"Intersection (Pass & Merit): {set_pass.intersection(set_merit)}")
    print(f"Union (Distinct Students): {set_pass.union(set_merit)}")
    print(f"Difference (Pass but no Merit): {set_pass.difference(set_merit)}")

# ============================================
# [span_14](start_span)PART 4: INTERACTIVE MENU SYSTEM[span_14](end_span)
# ============================================

# [span_15](start_span)Task 4.2: Eligibility Checker[span_15](end_span)
def check_eligibility(student):
    # [span_16](start_span)Criteria: CGPA >= 2.5 AND no outstanding courses AND active[span_16](end_span)
    is_eligible = student['cgpa'] >= 2.5 and student['outstanding_courses'] == 0 and student['is_active']

    status_msg = "is eligible for graduation." if is_eligible else "is NOT eligible for graduation."
    return is_eligible, f"{student['name']} {status_msg}"

def add_new_student():
    print("\n--- Add New Student ---")
    try:
        # [span_17](start_span)Task 2.2: Input and Validation[span_17](end_span)
        name = input("Enter name: ")
        matric = input("Enter matric number: ")
        age = int(input("Enter age: ")) # Task 2.2 Type Conversion[span_18](end_span)
        cgpa = float(input("Enter CGPA: ")) # Task 2.2 Type Conversion[span_19](end_span)

        # [span_20](start_span)Validation[span_20](end_span)
        if not (16 <= age <= 40) or not (0.0 <= cgpa <= 5.0):
            print("Validation Error: Age (16-40) or CGPA (0-5) out of range.")
            return

        is_active_input = input("Is the student active (yes/no): ").lower()
        is_active = True if is_active_input == 'yes' else False

        courses = input("Enter courses (comma separated): ").split(",")

        new_student = {
            "name": name,
            "matric": matric,
            "age": age,
            "cgpa": cgpa,
            "is_active": is_active,
            "courses": [c.strip() for c in courses],
            "outstanding_courses": 0
        }
        students.append(new_student)
        print("Student record added successfully.")

    except ValueError: # Task 2.2 Error Handling[span_21](end_span)
        print("Error: Please enter numeric values for Age and CGPA.")

def main():
    print("============================================")
    print("     Student Academic Performance System")
    print("============================================")

    while True:
        print("\nMenu Options:")
        print("1. View all students\n2. Add new student\n3. Check eligibility\n4. Find top performer\n5. Exit")

        choice = input("Enter your choice: ")

        # [span_22](start_span)Task 4.1: Build a Console Menu using MATCH CASE[span_22](end_span)
        match choice:
            case "1":
                for s in students: print(f"- {s['name']} ({s['matric']})")
            case "2":
                add_new_student()
            case "3":
                search = input("Enter student name: ")
                found = next((s for s in students if s['name'].lower() == search.lower()), None)
                if found:
                    _, msg = check_eligibility(found)
                    print(msg)
                else:
                    print("Student not found.")
            case "4":
                top = max(students, key=lambda x: x['cgpa'])
                print(f"Top Performer: {top['name']} (CGPA: {top['cgpa']})")
            case "5":
                print("Exiting... Goodbye!")
                break
            case _:
                print("Invalid choice.")

if __name__ == "__main__":
    main()
